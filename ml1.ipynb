# %%
import pandas as pd
datos = pd.read_csv('Celsius.csv')

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   celsius     7 non-null      int64
#  1   fahrenheit  7 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 244.0 bytes

# %%
datos.head()
# Out:
#    celsius  fahrenheit
# 0      -40       -40.0
# 1      -10        14.0
# 2        0        32.0
# 3        8        46.4
# 4       15        59.0

# %%
import seaborn as sb

sb.scatterplot(x="celsius",y="fahrenheit", data=datos,hue="fahrenheit",palette="coolwarm")
# Out:
# <Axes: xlabel='celsius', ylabel='fahrenheit'>

# %%
#Caracteristicas(X), Etiqueta(Y)
x = datos["celsius"]
y = datos["fahrenheit"]

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
xprocesada = x.values.reshape(-1,1)
yprocesada = y.values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression

modelo = LinearRegression()

# %%
modelo.fit(xprocesada, yprocesada)
# Out:
# LinearRegression()

# %%
celsius = 3000
prediccion = modelo.predict([[celsius]])
print(f"{celsius} grados celsius son {prediccion} grados fahrenheit")
# Out:
# 3000 grados celsius son [[5432.]] grados fahrenheit

# %%
import numpy as np

valores = input("Ingresa los valores en Celsius separados por espacios: ")

tempF = []

tempC = valores.split()

tempC = [int(valor) for valor in tempC]

print("Array:", tempC)

for elemento in tempC:
    tempF.append(modelo.predict([[elemento]]))
tempF = np.array(tempF).flatten().tolist()

df = pd.DataFrame()

df['Celsius']= tempC
df['Fahrenheit'] = tempF
print(df.head())
sb.scatterplot(x="Celsius",y="Fahrenheit", data=df,hue="Fahrenheit",palette="coolwarm")
# Out:
# Array: [10, 20, 30, 40, 50, 60, 70, 80, 90, 120, 140, 180, 220, 270]
#    Celsius  Fahrenheit
# 0       10        50.0
# 1       20        68.0
# 2       30        86.0
# 3       40       104.0
# 4       50       122.0
# <Axes: xlabel='Celsius', ylabel='Fahrenheit'>

# %%
modelo.score(xprocesada,yprocesada)
# Out:
# 1.0
